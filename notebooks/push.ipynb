# %% [markdown]
# ## Notebook to push an update from Drive via Colab notebook

# %% [markdown]
# 1.   Mount Drive
# 2.   CD to root directory in Drive of repo
# 3.   Set global user.email (this gets lost between Colab sessions)
# 4.   Run usual git cycle (add, commit, push) to update the remote repo

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! ls
# Out:
# drive  sample_data

# %%
# %cd /content/drive/MyDrive/machine_learning_tabular_book/code/deep_learning_basics
# Out:
# /content/drive/MyDrive/machine_learning_tabular_book/code/deep_learning_basics

# %%
! pwd
# Out:
# /content/drive/MyDrive/machine_learning_tabular_book/code/deep_learning_basics

# %% [markdown]
# Set the origin - I messed it up first time, so I needed to use set-url to correct it

# %%
# !git config --global user.email ryanmark1867

# %%
# !git add .

# %%
# !git commit -m "update elapsed timing"
# Out:
# [master 6e7076b] update elapsed timing
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite notebooks/model_training.ipynb (95%)

# %%
# !git push origin master
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 90.50 KiB | 6.96 MiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/ryanmark1867/deep_learning_basics.git
#    9f7856f..6e7076b  master -> master
